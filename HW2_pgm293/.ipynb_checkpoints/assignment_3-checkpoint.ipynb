# %%
# Author: Patrick Gitundu pgm293
##############################
# Assignment 1 of HW2
##############################

from __future__ import print_function

import csv
import os
import pandas as pd
#import seaborn
import pylab as pl

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
DFDATA = os.getenv('DFDATA')
print (DFDATA)
# Out:
# /gws/open/NYCOpenData/nycopendata/data

# %%
nycmvc = pd.read_csv(DFDATA + "/h9gi-nx95/1448475295/h9gi-nx95")
nycmvc.head()
# Out:
#          DATE   TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  11/22/2015  14:13     QUEENS   11369.0  40.763627 -73.881148
# 1  11/22/2015  14:12   BROOKLYN   11212.0  40.663518 -73.902376
# 2  11/22/2015  14:10        NaN       NaN        NaN        NaN
# 3  11/22/2015  14:10  MANHATTAN   10018.0  40.750661 -73.987779
# 4  11/22/2015   6:40     QUEENS   11420.0  40.665490 -73.819525
#
#                     LOCATION         ON STREET NAME CROSS STREET NAME  \
# 0   (40.763627, -73.8811477)              25 AVENUE         88 STREET
# 1   (40.663518, -73.9023763)          POWELL STREET    LIVONIA AVENUE
# 2                        NaN  YELLOWSTONE BOULEVARD     AUSTIN STREET
# 3  (40.7506611, -73.9877793)         WEST 35 STREET          BROADWAY
# 4  (40.6654902, -73.8195255)   NORTH CONDUIT AVENUE        122 STREET
#
#   OFF STREET NAME         ...          CONTRIBUTING FACTOR VEHICLE 2  \
# 0             NaN         ...                            Unspecified
# ...

# %%
#Tried dropping but got an indexing error with NULL values in the columns
#Tried the alternative below 
nycmvc[['ZIP CODE','LATITUDE','LONGITUDE','NUMBER OF PERSONS INJURED']].head()
# Out:
#    ZIP CODE   LATITUDE  LONGITUDE  NUMBER OF PERSONS INJURED
# 0   11369.0  40.763627 -73.881148                          1
# 1   11212.0  40.663518 -73.902376                          0
# 2       NaN        NaN        NaN                          0
# 3   10018.0  40.750661 -73.987779                          0
# 4   11420.0  40.665490 -73.819525                          0

# %%
ax = nycmvc.plot(x='LONGITUDE', y='LATITUDE', kind="scatter",alpha=0.2)
ax.set_title("Motor vehicle Collisions")

# %%
#Fill cells that do not havea Borough with the Text 'NO BOROUGH' to avoid indexing issues
mvcman = nycmvc[nycmvc['BOROUGH'].fillna('NO BOROUGH').str.contains("MANHATTAN")]
mvcman.head()
# Out:
#           DATE   TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 3   11/22/2015  14:10  MANHATTAN   10018.0  40.750661 -73.987779
# 7   11/22/2015   6:52  MANHATTAN   10016.0  40.741023 -73.978615
# 9   11/22/2015   7:05  MANHATTAN   10017.0  40.754348 -73.976972
# 17  11/22/2015   1:10  MANHATTAN   10016.0  40.743804 -73.983739
# 22  11/22/2015   8:20  MANHATTAN   10031.0  40.827153 -73.946201
#
#                      LOCATION     ON STREET NAME  CROSS STREET NAME  \
# 3   (40.7506611, -73.9877793)     WEST 35 STREET           BROADWAY
# 7     (40.741023, -73.978615)           2 AVENUE     EAST 28 STREET
# 9   (40.7543484, -73.9769721)     EAST 45 STREET  VANDERBILT AVENUE
# 17  (40.7438043, -73.9837386)  PARK AVENUE SOUTH     EAST 29 STREET
# 22  (40.8271531, -73.9462009)    WEST 148 STREET   AMSTERDAM AVENUE
#
#    OFF STREET NAME         ...          CONTRIBUTING FACTOR VEHICLE 2  \
# 3              NaN         ...                            Unspecified
# ...

# %%
mvcman.drop(['DATE', 'TIME', 'BOROUGH','LATITUDE','LONGITUDE',
       'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME', 'OFF STREET NAME',
        'NUMBER OF PEDESTRIANS INJURED','NUMBER OF PEDESTRIANS KILLED',
       'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED',
       'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED',
       'CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2',
       'CONTRIBUTING FACTOR VEHICLE 3', 'CONTRIBUTING FACTOR VEHICLE 4',
       'CONTRIBUTING FACTOR VEHICLE 5', 'UNIQUE KEY', 'VEHICLE TYPE CODE 1',
       'VEHICLE TYPE CODE 2', 'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4',
       'VEHICLE TYPE CODE 5'],axis=1,inplace=True)
mvcman.head()
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     ZIP CODE  NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED
# 3    10018.0                          0                         0
# 7    10016.0                          0                         0
# 9    10017.0                          1                         0
# 17   10016.0                          0                         0
# 22   10031.0                          0                         0

# %%
ax = mvcman.plot(x='ZIP CODE', y='NUMBER OF PERSONS INJURED', kind="scatter",alpha=0.2,label="Zip Code vs People Injured")
ax.set_title("Motor Vehicle Collisions Manhattan")
#Tried adding some text but my kernel keeps crashing

# %%
ax = mvcman.plot(x='ZIP CODE', y='NUMBER OF PERSONS KILLED', kind="scatter",alpha=0.2,label="Zip Code vs Number of Persons Killed")
ax.set_title("Motor Vehicle Collisions Manhattan")

# %%
ax = mvcman.plot(x='ZIP CODE', y='NUMBER OF PERSONS INJURED', kind="scatter",alpha=0.2,color="SteelBlue")
ax.set_title("Motor Vehicle Collisions Manhattan")

mvcman.plot(x='ZIP CODE', y='NUMBER OF PERSONS KILLED', alpha=0.1, kind="scatter", ax=ax, color="IndianRed")
ax.set_title("Motor Vehicle Collisions Manhattan")
