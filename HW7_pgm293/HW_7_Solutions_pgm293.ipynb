# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
from collections import Counter
from itertools import chain

from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('MOCK_DATA.csv')
df.head()
# Out:
#    id first_name last_name                     email  gender      ip_address
# 0   1   Kimberly      Hart    khart0@arstechnica.com  Female    130.35.152.6
# 1   2    William    Greene  wgreene1@istockphoto.com    Male  214.106.85.145
# 2   3      Craig     Hayes    chayes2@eventbrite.com    Male   92.27.161.105
# 3   4     Sharon      West      swest3@wikipedia.org  Female    82.66.76.169
# 4   5       Anna   Daniels       adaniels4@goo.ne.jp  Female  173.174.205.34

# %%
df_counts = df['first_name'].value_counts()
df_counts[:]
# Out:
# Debra        16
# Julie        11
# Paula        11
# Ralph        11
# Wayne        11
# Lawrence     11
# Shawn        10
# Terry        10
# Christina    10
# Brian        10
# Anna          9
# Carlos        9
# Jean          9
# Melissa       9
# Deborah       9
# Susan         9
# Wanda         9
# Joan          9
# Juan          9
# Gregory       8
# Annie         8
# Samuel        8
# Judith        8
# Kathy         8
# Peter         8
# Henry         8
# Shirley       7
# Scott         7
# Judy          7
# Jessica       7
#              ..
# Beverly       3
# Douglas       3
# Doris         3
# Pamela        3
# Adam          3
# Rachel        2
# Carolyn       2
# Paul          2
# Jeffrey       2
# Jennifer      2
# Jane          2
# Cheryl        2
# Arthur        2
# Keith         2
# Teresa        2
# Jason         2
# Bruce         2
# Phyllis       2
# Christine     2
# Donna         2
# Jimmy         2
# Eric          1
# Russell       1
# Julia         1
# ...

# %%
#borrowed from stackoverflow
from wordcloud import WordCloud, STOPWORDS
tuples = tuple([tuple(x) for x in df['first_name'].value_counts().reset_index().values])
wordcloud = WordCloud(stopwords=STOPWORDS,background_color='white',width=1200,height=1000).generate_from_frequencies(tuples)

plt.figure( figsize=(20,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
